# %% [markdown]
# # SLIC Segmentation

# %%
import matplotlib.pyplot as plt
import sys
import os

sys.dont_write_bytecode = True

from src.utils import load_image, load_gt, compute_jaccard_score, compute_boundary_recall
from src.segmentation.SLIC import SLIC

# %%
ROOT = os.getcwd()
INDEX = 24063

# %%
image_path = f'data\\images\\train\\{INDEX}.jpg'
ground_path = f'data\\ground_truth\\train\\{INDEX}.mat'

# %%
original_image = load_image(image_path)
segmented_image, mask, labels = SLIC(original_image, num_segments=2000, compactness=10)
gt_segmentation_bin = load_gt(ground_path)

# %%
plt.figure(figsize=(12, 8))
plt.subplot(1, 4, 1), plt.imshow(original_image, cmap='gray'), plt.title('Original Image')
plt.subplot(1, 4, 2), plt.imshow(segmented_image, cmap='gray'), plt.title('Segmented Image')
plt.subplot(1, 4, 3), plt.imshow(mask, cmap='gray'), plt.title('Mask Image')
plt.subplot(1, 4, 4), plt.imshow(gt_segmentation_bin, cmap='gray'), plt.title('Ground Truth Segmentation')
plt.show()

# %%
jaccard_score = compute_jaccard_score(mask, gt_segmentation_bin)
recall_score = compute_boundary_recall(mask, gt_segmentation_bin)
print(f"Jaccard Score : {jaccard_score}\nBoundary Recall Score : {recall_score}")
# Out:
# Jaccard Score : 0.5609
# Boundary Recall Score : 1.0
